# %% [markdown]
# <center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240" height="100" /></center>
#
# # <center><b>Data Visualization in Python<b></center>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# 1. [**Introduction**](#Section1)<br>
#   - 1.1 [**Data Visualization**](#Section11)
#   - 1.2 [**Need of Visualization**](#Section12)
#   - 1.3 [**Importance of Visualization**](#Section13)
#   - 1.4 [**Advantages of Visualization**](#Section14)
#   - 1.5 [**Types of Visualization**](#Section15)
# 2. [**Plotting Packages in Python**](#Section2)<br>
#   - 2.1 [**Installing Libraries**](#Section21)<br>
#   - 2.2 [**Upgrading Libraries**](#Section22)<br>
#   - 2.3 [**Importing Libraries**](#Section23)<br>
# 3. [**Basics Intro to Matplotlib, Pandas, and Seaborn**](#Section3)
#   - 3.1 [**Intro to Visualization using Matplotlib**](#Section31)<br>
#   - 3.2 [**Intro to Visualization using Pandas**](#Section32)<br>
#   - 3.3 [**Intro to Visualization using Seaborn**](#Section33)<br>
# 4. [**Data Acquistion & Wrangling**](#Section4)
# 5. [**Univariate Plotting**](#Section5)
#   - 5.1 [**Bar Charts**](#Section51)<br>
#   - 5.2 [**Line Charts**](#Section52)<br>
#   - 5.3 [**Area Charts**](#Section53)<br>
#   - 5.4 [**Histogram**](#Section54)<br>
#   - 5.5 [**KDE Plot**](#Section55)<br>
#   - 5.6 [**Donut Chart**](#Section56)<br>
# 6. [**Bivariate Plotting**](#Section6)
#   - 6.1 [**Scatter Plot**](#Section61)<br>
#   - 6.2 [**Regression Plot**](#Section62)<br>
#   - 6.3 [**Hexplot**](#Section63)<br>
#   - 6.4 [**Stacked Bar Chart**](#Section64)<br>
#   - 6.5 [**Bivariate Line Chart**](#Section65)<br>
#   - 6.6 [**Pairplot**](#Section66)<br>
# 7. [**Multivariate Plotting**](#Section7)
#   - 7.1 [**Multivariate Scatter Plot**](#Section71)<br>
#   - 7.2 [**Grouped Boxplot**](#Section72)<br>
#   - 7.3 [**Heatmap**](#Section73)<br>
#   - 7.4 [**Parallel Coordinates**](#Section74)<br>
#   - 7.5 [**Violin Plot**](#Section75)<br>

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
#
# <a name = Section11></a>
# ### **1.1 Data Visualization**
#
# - Data visualization refers to the visualization of information from data in a graphical representation.
#
# - It is one of the **core skills** of a **data scientist** to analyze the data and build useful models for businesses.
#
# <center><img src="https://www.inzata.com/wp-content/uploads/2019/06/shutterstock_488322949.jpg"></center>
#
# - An in-depth **analysis** is **always required** before concluding the final solution, even if the person is not a subject matter expert.
#
# - It is one of the **most important** and **critical tool** in your arsenal which is hard to master.
#
# - Data visuals can help us **understand** the **problem better** resulting higher chances of finding better solution.<br>
#
# <a name = Section12></a>
# ### **1.2 Need of Visualization**
#
# - Visual representation helps humans to inspect and understand better.
#
# - **Humans process visual inputs better and faster than all other types of inputs**. This is the key reason for visualizing data.
#
# - When the representation of data is pictorial it’s easier to find patterns, digest the data and develop insights to solve the problems.
#
# <center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/gp-2.png?raw=true" width=75%></center>
#
# - From the above figure you can see that its easier for us to process images rather than text.
#
# - The **visuals** are **processed X60 times faster** than texts.
#
# <a name = Section13></a>
# ### **1.3 Importance of Visualization**
#
# - Helping decision makers understand how the business data is being interpreted to **determine business decisions** or goals.
#
# - Leading the target audience to focus on **business insights** to **discover areas** that require attention.
#
# - Handling large amounts of data in a pictorial format to provide a **summary** of **unseen patterns** in the data.
#
# - To **manage growth** and **converting trends** into business strategies by **making sense** of your information.
#
# - **Revealing** previously **unnoticed key points** about the data sources to help decision makers compose data analysis reports.
#
# <a name = Section14></a>
# ### **1.4 Advantages of Visualization**
#
# - Better Analysis
#
# - Quick Action
#
# - Identify Patterns
#
# - Finding Errors
#
# - Understanding the Story
#
# - Exploring Business Insights
#
# - Grasping the Latest Trends
#
# <a name = Section15></a>
# ### **1.5 Types of Visualization**
#
# - On the basis of the number of variables you want to see relationship in between, plotting can be classified as:
#
#   - **Univariate Plotting:** Describe a type of data which consists of observations on only a single characteristic or attribute.
#
#   - **Bivariate Plotting:** Describe a type of data which consists of observations on two characteristics or attribute.
#
#   - **Multivariate Plotting:** Describe a type of data which consists of observations on more than two characteristics or attribute.

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Plotting Packages in Python**
# ---
#
# - There are **various packages available** in Python to plot visuals such as **matplotlib, pandas, seaborn, bokeh, plotly**, etc.
#
# - Each package has its utility and its use depends on the type of information you want to extract.
#
# - Here we will mainly use matplotlib, pandas, seaborn, bokeh, and plotly.

# %% [markdown]
# <a name = Section21></a>
# ### **2.1 Installing Libraries**
#
# - If you are using Anaconda, you can open up your **Anaconda Navigator**, and then search and install the libraries directly.
#
# - If you are using **Anaconda Command Prompt**, then use the following instruction without an exclamation mark (!).
#
# - You can use $--user$ at the end of the instruction in case you see "requires an administrative permission".

# %%
# !pip install -q matplotlib seaborn bokeh plotly

# %% [markdown]
# <a name = Section22></a>
# ### **2.2 Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell above (2.1) and below (2.2) again after restarting the runtime.

# %%
# pip install matplotlib
# pip install plotly
# pip install bokeh
# pip install seaborn

# %%
# !pip install -q --upgrade pip
# !pip install -q --upgrade matplotlib seaborn bokeh plotly chart-studio

# %% [markdown]
# <a name = Section23></a>
# ### **2.3 Importing Libraries**

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing for panel data analysis
pd.set_option('display.max_columns', None)                          # Unfolding hidden features if the cardinality is high
pd.set_option('display.max_colwidth', None)                         # Unfolding the max feature width for better clearity
pd.set_option('display.max_rows', None)                             # Unfolding hidden data points if the cardinality is high
pd.set_option('mode.chained_assignment', None)                      # Removing restriction over chained assignments operations
pd.set_option('display.float_format', lambda x: '%.5f' % x)         # To suppress scientific notation over exponential values
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface using matplotlib
import seaborn as sns                                               # Importing seaborm library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
from bokeh.layouts import column                                    # To build a grid of plots and widgets
from bokeh.plotting import Figure                                   # Create a new figure for plotting
from bokeh.plotting import show                                     # Show the figure result
from bokeh.plotting import output_notebook                          # Helper that enables ouput in the notebook
from bokeh.plotting import output_file                              # Generate output saved to a file when show() is called
from bokeh.models import ColumnDataSource                           # Populate columns by making Ajax calls to REST endpoints
from bokeh.models import CustomJS                                   # Attaches CustomJS callbacks to property change events
from bokeh.models import Slider                                     # For custom JS slider widgets
from bokeh.models import HoverTool                                  # Displays informational tooltips over a glyph
from bokeh.io import push_notebook                                  # Update Bokeh plots in a Jupyter notebook output
output_notebook()
#-------------------------------------------------------------------------------------------------------------------------------
from plotly import graph_objs as go                                 # Contains an auto-generated hierarchy of Python classes
from plotly.offline import iplot                                    # Display Figures in offline mode
#-------------------------------------------------------------------------------------------------------------------------------
from ipywidgets import interact                                     # Creates UI controls for exploring code and data
import warnings                                                     # Importing warning to disable runtime warnings
warnings.filterwarnings("ignore")                                   # Warnings will appear only once
# Out:
# /Users/vasu/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ---
# <a name = Section3></a>
# # **3. Basics Intro to Matplotlib, Pandas, and Seaborn**
# ---

# %% [markdown]
# <a name = Section31></a>
# ### **3.1 Intro to Visualization using Matplotlib**
#
# - <a href="https://matplotlib.org/">**Matplotlib**</a> is a plotting library for the Python programming language and its numerical mathematics extension NumPy.
#
# - It provides an **object-oriented API** for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, etc.
#
# - It helps in **developing publication quality plots** with just a few lines of code.
#
# - You can use interactive figures that can zoom, pan, update...
#
# - You can also take full control of line styles, font properties, axes properties...
#
# - You can export and embed to a number of file formats and interactive environments.
#
# - We generally use <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html#module-matplotlib.pyplot">**pyplot interface**</a> of matplotlib to plot interactive graphs for data analysis.
#
# - To use the pyplot interface of matplotlib we load the interface with alias of plt as shown below:
#
# **<center><h3><font color="red">from matplotlib import pyplot as plt</font></h3></center>**
#
# - This interface can also be used with **3rd party packages** that uses matplotlib. For example, seaborn.
#
# - In addtion to this interface we also uses inline <a href="https://ipython.readthedocs.io/en/stable/interactive/tutorial.html#magics-explained">**magic functions**</a> of the notebook and that is:
#
# **<center><h3><font color="red">%matplotlib inline</font></h3></center>**
#
# - It sets the backend of matplotlib to the '$inline$' backend.
#
# - The ouput of plotting commands is displayed inline within frontends like the Jupyter notebook.
#
# - The resulting plots will then also be **stored in the notebook** document.

# %% [markdown]
# <a name = Section32></a>
# ### **3.2 Intro to Visualization using Pandas**
#
# - Pandas is a **software library** written for the Python programming language for **data manipulation** and **analysis**.
#
# - But it can **also** be **used for plotting** interactive visualization because pandas is built on top of numpy & matplotlib.
#
# - It provides the **basic interface** of the plot to easily create decent-looking plots.
#
# - The plot method on Series and DataFrame is just **a simple wrapper** around plt.plot().
#
# - The explicit custom designs are still possible with the help of the matplotlib pyplot interface.
#
# - The general syntax that is used for plotting is as follows:
#
# **<center><h3><font color="red">dataframe.plot(kind="<-type of plot->")</font></h3></center>**
#
# - To get more information about the types of plot click <a hre="https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html">**here**</a>.

# %% [markdown]
# <a name = Section33></a>
# ### **3.3 Intro to Visualization using Seaborn**
#
# - Seaborn is a Python data visualization library based on matplotlib.
#
# - It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# - The explicit custom designs are still possible with the help of the matplotlib pyplot interface.
#
# - The general syntax that is used for plotting is as follows:
#
# **<center><h3><font color="red">seaborn.<-plot name->(data)</font></h3></center>**
#
# - Click <a hre="https://seaborn.pydata.org/introduction.html">**here**</a> to know more about how to get started to searbon plots.

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Wrangling**
# ---
#
# - There are two datasets of McDonald's India that we will be using to perform visualization, and they are:
#   - Nutrition facts about different items on McDonald's menu: **Shown in left table**.
#
#   - McDonald's store location information: **Shown in right table**.
#
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/Mcd.png"></center>
#
#
# |Dataset| Records | Features | Dataset Size |
# | :--: | :--: | :--: | :--: |
# | McDonald's menu | 83 | 14 | 10.8 KB |
# | McDonald's store location | 40 | 18 | 17.7 KB|
#
# <br>
#
# |Id|Features|Description||Id|Features|Description|
# |:--|:--|:--||:--|:--|:--|
# |01|**Category**|The category to which an item belong to.||01|**Brand**|Brand name.|
# |02|**Item**|Name of the item.||02|**Store ID**|ID of the store. |
# |03|**Serve_Size**|The weight of a single serving (g).||03|**Store Name**|Name of the store.|
# |04|**Energy**|Number of calories in the item (kcal).||04|**Street Address**|Address of the store.|
# |05|**Protein**|Protein in the item (g).||05|**City**|City of the store.|
# |06|**Total_Fat**|Total Fat in the item (g).||06|**State**|State of the store.|
# |07|**Saturated_Fat**|Saturated Fat in the item (g).||07|**Postcode**|Postcode of the store.|
# |08|**Trans_Fat**|Trans Fat in the item (g).||08|**Longitude**|Longitude of the store.|
# |09|**Cholestrol**|Cholestrol in the item (mg).||09|**Latitude**|Latitude of the store.|
# |10|**Carbohydrates**|Carbohydrates in the item (g).||10|**Revenue**|Revenue of the store.|
# |11|**Sugar**|Sugars in the item (g).||11|**Profits**|Profit of the store.|
# |12|**Dietary_Fibre**|Dietary Fibres in the item (g).||12|**Selling Price**|Total selling price of items of the store.|
# |13|**Sodium**|Sodium in the item (mg).||13|**Cost Price**|Total cost price of items of the store.|
# |14|**High_Or_Low_Sugar**|Sugar levels wheter high or low.||14|**Gross Profit Margin**|Gross profit margin of the store.|
# |||||15|**Number of Employees**|Number of employees of the store.|
# |||||16|**Customers**|Average number of customers.|
# |||||17|**Most Prefered Meal**|Most selling item of the store.|
# |||||18|**Most Selling Item**|Most selling item of the store.|

# %%
# Nutrition facts about different items for McDonald's menu.
df_mcd = pd.read_excel(io='mcdonalds_india_menu.xlsx')

# McDonald's store location information.
df_store = pd.read_excel(io='mcdonalds_store_data.xlsx')

# Display data dimensions
print('McDonalds Menu Shape:', df_mcd.shape)
print('McDonalds Store Location Shape:', df_store.shape)
# Out:
# McDonalds Menu Shape: (83, 15)
# McDonalds Store Location Shape: (40, 19)

# %%
df_mcd.head(5)
# Out:
#    Unnamed: 0   Category                  Item  Serve_Size  Energy  Protein  \
# 0           0  Breakfast     Egg & Cheese Muﬃn         112     290       14
# 1           1  Breakfast        Sausage McMuﬀm         112     273       16
# 2           2  Breakfast  Sausage & Egg McMuﬀm         157     355       22
# 3           3  Breakfast            Veg McMuﬀm         119     299       10
# 4           4  Breakfast      Veg Supreme Muﬃn         139     299        7
#
#    Total_Fat  Saturated_Fat  Trans_Fat  Cholestrol  Carbohydrates  Sugars  \
# 0         13        7.00000    0.20000         244             28       2
# 1         11        5.70000    0.20000          50             28       2
# 2         17        7.90000    0.20000         277             29       2
# 3         12        7.20000    0.20000          21             38       3
# 4         13        5.20000    0.20000          11             39       4
#
#    Dietary_Fibre Sodium High_Or_Low_Sugar
# ...

# %%
df_mcd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Category           83 non-null     object
#  1   Item               83 non-null     object
#  2   Serve_Size         83 non-null     int64
#  3   Energy             83 non-null     int64
#  4   Protein            83 non-null     int64
#  5   Total_Fat          83 non-null     int64
#  6   Saturated_Fat      83 non-null     float64
#  7   Trans_Fat          83 non-null     float64
#  8   Cholestrol         83 non-null     int64
#  9   Carbohydrates      83 non-null     int64
#  10  Sugars             83 non-null     int64
#  11  Dietary_Fibre      83 non-null     int64
#  12  Sodium             83 non-null     object
#  13  High_Or_Low_Sugar  83 non-null     object
# dtypes: float64(2), int64(8), object(4)
# memory usage: 9.2+ KB

# %%
df_mcd['Sodium'] = pd.to_numeric(df_mcd['Sodium'], errors='coerce')

# %%
df_mcd.describe()
# Out:
#        Unnamed: 0  Serve_Size    Energy  Protein  Total_Fat  Saturated_Fat  \
# count    83.00000    83.00000  83.00000 83.00000   83.00000       83.00000
# mean     41.00000   192.01205 239.67470  6.44578    9.53012        4.20241
# std      24.10394   115.63246 166.35776  7.21322   10.74804        4.58146
# min       0.00000     9.00000   0.00000  0.00000    0.00000        0.00000
# 25%      20.50000   113.50000 131.00000  0.00000    0.00000        0.00000
# 50%      41.00000   167.00000 207.00000  4.00000    6.00000        3.60000
# 75%      61.50000   249.00000 331.00000 10.00000   15.00000        6.05000
# max      82.00000   500.00000 808.00000 26.00000   51.00000       24.10000
#
#        Trans_Fat  Cholestrol  Carbohydrates   Sugars  Dietary_Fibre     Sodium
# count   83.00000    83.00000       83.00000 83.00000       83.00000   68.00000
# mean     0.11325    25.80723       32.03614 15.87952        1.28916  532.64706
# ...

# %%
df_mcd['Category'].value_counts()
# Out:
# Cold Beverages          18
# Desserts                17
# Sandwiches and Wraps    11
# Breakfast                8
# Shake                    6
# Condiments               5
# New Products             5
# Snacks                   4
# Hot Beverages            4
# Nuggets                  3
# Chicken Wings            2
# Name: Category, dtype: int64

# %%
df_mcd['High_Or_Low_Sugar'].value_counts()
# Out:
# High Sugar    45
# Low Sugar     38
# Name: High_Or_Low_Sugar, dtype: int64

# %% [markdown]
# **Note:**
#
# - In real life scenario, you may need to clean the data first, and then perform the analysis using visualization.
#
# - Here we will be **performing visualization** on the **pre-processed data**.
#
# - The **objective** is to **understand** the practical **working** of visuals than solving business problems.
#
# - Before diving in plotting of visuals it is advisable to get to know about the <a href="https://matplotlib.org/stable/gallery/showcase/anatomy.html">**Anatomy of a Figure**</a>

# %%
df_store.head()
# Out:
#         Brand      Store ID     Store Name  \
# 0  McDonald's  23149-228271  Banjara Hills
# 1  McDonald's  23191-228548     Kukatpally
# 2  McDonald's  23193-228546       Madhapur
# 3  McDonald's  23180-228545  Jubilee Hills
# 4  McDonald's  24457-238129   Hi-Tech City
#
#                                                                   Street Address  \
# 0                      Lower Ground Floor, GVK One, Road Number 1, Banjara Hills
# 1                              Upper Ground Floor, Forum Sujana Mall, Kukatpally
# 2                                     Lower Ground Floor, Inorbit Mall, Madhapur
# 3                 Ground Floor, Road No. 92, Near Apollo hospital, Jubilee Hills
# 4  Upper Ground Floor, Phoenix tower A, Opposite Trident Hotel, Madhapur Village
#
#         City State  Postcode  Longitude  Latitude       Revenue       Profits  \
# 0  Hyderabad    AP    500034   78.45000  17.42000 2117343.66894  171583.86521
# ...

# %%
df_store.shape
# Out:
# (40, 19)

# %%
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           40 non-null     int64
#  1   Brand                40 non-null     object
#  2   Store ID             40 non-null     object
#  3   Store Name           40 non-null     object
#  4   Street Address       40 non-null     object
#  5   City                 40 non-null     object
#  6   State                40 non-null     object
#  7   Postcode             40 non-null     int64
#  8   Longitude            40 non-null     float64
#  9   Latitude             40 non-null     float64
#  10  Revenue              40 non-null     float64
#  11  Profits              40 non-null     float64
#  12  Selling Price        40 non-null     float64
#  13  Cost Price           40 non-null     float64
#  14  Gross Profit Margin  40 non-null     float64
# ...

# %%
df_store['Number of Employees'] = df_store['Number of Employees'].round()
df_store['Customers'] = df_store['Customers'].round()

# %%
# df_store.rename(columns={'Brand': 'Brand new harshal Name'})

# %%
df_store.describe()
# Out:
#        Unnamed: 0     Postcode  Longitude  Latitude       Revenue  \
# count    40.00000     40.00000   40.00000  40.00000      40.00000
# mean     19.50000 282836.45000   77.45250  22.99000 4947851.49693
# std      11.69045 211483.34964    0.45629   7.03255 2536534.32659
# min       0.00000 110001.00000   77.05000  12.91000 1001098.66634
# 25%       9.75000 110037.00000   77.11750  16.31750 2682676.16810
# 50%      19.50000 122001.50000   77.22000  28.48000 4968245.49089
# 75%      29.25000 515063.25000   77.61750  28.55250 6873332.92642
# max      39.00000 560095.00000   78.45000  28.69000 9754173.40617
#
#             Profits  Selling Price    Cost Price  Gross Profit Margin  \
# count      40.00000       40.00000      40.00000             40.00000
# mean   964240.88510  2628607.48984 2120507.78440         508099.70544
# std    802438.91630   808152.24728 1087086.13997         536159.45548
# min     50085.48536   850866.65190  429042.28557       -1107573.63456
# ...

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Univariate Plotting**
# ---
#
# |<center>Bar Chart</center>|<center>Line Chart</center>|<center>Area Chart</center>|<center>Histogram</center>|<center>Donut Chart</center>|
# |:--:|:--:|:--:|:--:|:--:|
# |<img src="https://i.imgur.com/skaZPhb.png">|<img src="https://i.imgur.com/gaNttYd.png">|<img src="https://i.imgur.com/pampioh.png">|<img src="https://i.imgur.com/OSbuszd.png">|<img src="https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/3-Donut-Chart.png">|
# |df.plot.bar()|df.plot.line()|df.plot.area()|df.plot.hist()|	df.plot.pie()|
#
# <center><h4><strong>Disclaimer:</strong> The images are only for illustration purpose. Please don't compare them with our data.</h4></center>
#
# - The **pandas** library is the **core library** to perform data analysis.
#
# - However, it can **do more than loading** and **transforming** your **data**, it can visualize it too!
#
# - Indeed, the **easy-to-use** and **expressive** pandas **plotting API** is a big reason behind pandas popularity.
#
# - In this section we will **learn** the **basic** pandas **plotting facilities**, starting with univariate plots.
#
# - We will get an understanding of pandas plotting library structure, and spend some time examining data types.

# %% [markdown]
# <a name = Section51></a>
# ### **5.1 Bar Chart**
#
# - Bar chart is one of the simplest tool for data visualization because they **map categories** to **numbers**.
#
#
# - They are useful for **categorical data** that doesn’t have a lot of different categories.
#
# - For pandas's barplot official documentation click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html">**here**</a>.

# %%
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
### RIGHT NOW

# %%
fig, axis = plt.subplots(figsize=(14, 6))   # figsize =(w, h)

df_mcd['Category'].value_counts().plot(kind='bar',
                                       ax=axis,  # canvas / axis
                                       #color=['#1B9E77']
                                      )
plt.ylabel("Count of Items")
plt.xlabel("Category Name")
plt.title("Number of Unique Items per category")

# # PUTTING ON DATA LABELS
# for p in ax.patches:
#     text = str(p.get_height())
#     x_cord = p.get_x() + 0.15
#     y_cord = p.get_height() + 0.2
#     ax.annotate(text, (x_cord, y_cord))

plt.grid(axis='y', linestyle=':')
plt.tight_layout()
plt.savefig("NameofFileTOSaveAs.png")

# %%
# df_mcd.groupby('Category').agg({'Sodium': 'mean', 'Cholestrol': 'mean'})

# %%
# fig, ax = plt.subplots(figsize=(14, 7))

# (df_mcd
#  #.assign(Protein=df_mcd['Protein']*1000)
#  .groupby('Category')
#  .agg({'Protein': ['mean', 'std']})
#  .plot(kind='bar', ax=ax))

# plt.grid(linestyle=':')
# plt.ylabel("MG per serve")
# plt.tight_layout()

# %%
df_mcd
# Out:
#     Unnamed: 0              Category                                    Item  \
# 0            0             Breakfast                       Egg & Cheese Muﬃn
# 1            1             Breakfast                          Sausage McMuﬀm
# 2            2             Breakfast                    Sausage & Egg McMuﬀm
# 3            3             Breakfast                              Veg McMuﬀm
# 4            4             Breakfast                        Veg Supreme Muﬃn
# 5            5             Breakfast              Hot Cakes with Maple Syrup
# 6            6             Breakfast                              Hash Brown
# 7            7             Breakfast                            McEgg Burger
# 8            8  Sandwiches and Wraps                    Chicken Maharaja Mac
# 9            9  Sandwiches and Wraps                               McChicken
# 10          10  Sandwiches and Wraps                            Filet-0-Fish
# ...

# %%
protein_content_per_category = (df_mcd
                                 .groupby('Category')   # key of grouping by
                                 .agg({'Protein': 'mean'})
                                 .sort_values('Protein', ascending=False))     # aggregations we want

# %%
fig, axis = plt.subplots(figsize=(14, 7))  # w,h

protein_content_per_category.plot(kind='bar', ax=axis)

plt.grid(linestyle=':')
plt.ylabel("MG per serve")
plt.title("Average Protein content per category")
plt.legend().remove()

# %%
# fig, ax = plt.subplots(figsize=(14, 7))

# (df_mcd
#  #.assign(Protein=df_mcd['Protein']*1000)
#  .groupby('Category')
#  .agg({'Protein': 'mean', 'Carbohydrates': 'mean'})
#  .plot(kind='bar', ax=ax))

# plt.grid(linestyle=':')
# plt.ylabel("MG per serve")
# plt.tight_layout()

# %%
# 1 TO REMOVE DUP ITEMS : 
df_mcd.groupby(['Item', 'Category']).mean().reset_index()

# %%
# 2 TO REMOVE DUP ITEMS
df_mcd.drop_duplicates(subset=['Item'], keep='first')

# %%
# Extracting labels of Category in a list
x_value = df_mcd['Category'].value_counts().index.to_list()

# Extracting total count for each category
y_value = df_mcd['Category'].value_counts().values

# Display the extracted values
print('x-axis values:', x_value)
print('y-axis values', y_value)
# Out:
# x-axis values: ['Cold Beverages', 'Desserts', 'Sandwiches and Wraps', 'Breakfast', 'Shake', 'Condiments', 'New Products', 'Snacks', 'Hot Beverages', 'Nuggets', 'Chicken Wings']
# y-axis values [18 17 11  8  6  5  5  4  4  3  2]

# %%
# Creating a custom figure size of 15 X 7 inches
figure = plt.figure(figsize=[15, 7])

# Using magic of pandas's bar function
df_mcd['Category'].value_counts().plot.bar(color='#1B9E77')

# Changing x-ticks label size to 12 and rotating to 90 degrees
plt.xticks(rotation=90, size=12)

# Changing y-ticks value using an array of 19 value with step size of 2
plt.yticks(ticks=np.arange(0, 19, 2), size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Category', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Number of Items', size=14)

# Labelling title with a custom label and size of 16
plt.title(label='Number of Items per Category', size=16)

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can observe that the **Cold Beverages** category is the **highest selling category** amongst other categories.
#
# - What if we want to know the **percentage** of total **Cold Beverages** or **Desserts**?
#
#
# - This bar chart plots the __absolute numbers__, but we can also plot the __relative proportions__ of each category.

# %%
# Extracting labels of Category in a list
x_value = df_mcd['Category'].value_counts().index.to_list()

# Extracting proportion values for each category
y_value = df_mcd['Category'].value_counts().values / len(df_mcd)

# Display the extracted values
print('x-axis values:', x_value)
print('y-axis values', y_value)
# Out:
# x-axis values: ['Cold Beverages', 'Desserts', 'Sandwiches and Wraps', 'Breakfast', 'Shake', 'Condiments', 'New Products', 'Snacks', 'Hot Beverages', 'Nuggets', 'Chicken Wings']
# y-axis values [0.21686747 0.20481928 0.13253012 0.09638554 0.07228916 0.06024096
#  0.06024096 0.04819277 0.04819277 0.03614458 0.02409639]

# %%
# Out:
# 82

# %%
fig, axis = plt.subplots(figsize=(14, 5))

((df_mcd['Category'].value_counts() / df_mcd['Item'].nunique())*100).plot(kind='bar', ax=axis)
plt.ylabel("Percentage Contribution to Items")
plt.xlabel("Category")
plt.title("Percentage of Items by Category ")
# Out:
# Text(0.5, 1.0, 'Percentage of Items by Category ')

# %%
# # Creating a custom figure size of 15 X 7 inches
# figure = plt.figure(figsize=[15, 7])

# # Using magic of pandas bar function
# (df_mcd['Category'].value_counts() / len(df_mcd)).plot.bar(color='#3F617A')

# # Changing x-ticks label size to 12 and rotating to 90 degrees
# plt.xticks(rotation=90, size=12)

# # Changing y-ticks value using an array of size 0.3 with a step size of 0.05
# plt.yticks(ticks=np.arange(0, 0.3, 0.05), size=12)

# # Labelling x-axis with a custom label and size of 14
# plt.xlabel(xlabel='Category', size=14)

# # Labelling y-axis with a custom label and size of 14
# plt.ylabel(ylabel='Number of Items', size=14)

# # Labelling title with a custom label and size of 16
# plt.title(label='Number of Items per Category', size=16)

# # Dispaly the output by rendering visual on the screen
# plt.show()

# %% [markdown]
# **Observation:**
#
# - We can observe that **60% items** belong to the **Cold Beverages, Desserts** and **Sandwiches and Wraps**.

# %% [markdown]
# <a name = Section52></a>
# ### **5.2 Line Chart**
#
# - A line chart is a **series of data points** with a continuous line.
#
# - They are also **good** for **depicting trends** for **different categories** over the same period of time, to aid comparison.
#
# - For pandas's lineplot official documentation click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.line.html">**here**</a>.

# %%
energy_per_item = df_mcd.groupby("Item").agg({'Energy': 'mean'}).sort_values(by='Energy', ascending=False)

# %%
# Creating a custom figure size of 15 X 7 inches
fig, ax  = plt.subplots(figsize=(24, 7))

# Using magic of pandas line() function
energy_per_item.plot(kind='area', linestyle='-.', ax=ax)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Item Name', size=16)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Energy (in kcal)', size=16)

# Labelling title with a custom label and size of 16
plt.title(label='Variation of Energy Across Different Items', size=20)

# Enable the grid view in background
plt.grid(b=True,  linestyle=':')

# %%
# Analyze foods having high engergy in specified range index
df_mcd.iloc[:28]['Category'].value_counts()
# Out:
# Sandwiches and Wraps    11
# Breakfast                8
# Snacks                   4
# Nuggets                  3
# Chicken Wings            2
# Name: Category, dtype: int64

# %% [markdown]
# **Observation:**
#
# - This plot shows the **trend** followed by **amount of calories** (Energy) present in different items on our menu.
#
# - The **menu items** at the **beginning** of the dataset have a **very high energy** when **compared to** the **items at the end**.

# %% [markdown]
# <a name = Section53></a>
# ### **5.3 Area Chart**
#
# - Area charts are line charts, but with the **area under** the **shaded line**.
#
# - They are useful in identifying overall **volume**, as well as the **proportion** taken up by each category.
#
# - For pandas area plot official documentation click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.area.html">**here**</a>.

# %%
# Creating a custom figure size of 15 X 7 inches
figure = plt.figure(figsize=[15, 7])

# Using magic of pandas area() function
df_mcd['Total_Fat'].plot.area()

# Changing x-ticks ranging from 0 to 90 with step size of 5 and label size of 12
plt.xticks(ticks=np.arange(0, 90, 5), size=12)

# Changing y-ticks ranging from 0 to 55 with step size of 5 and label size of 12
plt.yticks(ticks=np.arange(0, 55, 5), size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Index', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Total Fat', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Variation of Total Fat across Different Items', size=16)

# Dispaly the output by rendering visual on the screen
plt.show()

# %%
df_mcd.iloc[15:28]['Category'].value_counts()
# Out:
# Sandwiches and Wraps    4
# Snacks                  4
# Nuggets                 3
# Chicken Wings           2
# Name: Category, dtype: int64

# %% [markdown]
# **Observation:**
#
# - **Sandwiches and Wraps, Snacks, Nuggets, Chicken Wings** categorys are found to have **high Total Fat**.

# %% [markdown]
# <a name = Section54></a>
# ### **5.4 Histogram**
#
# - It is a graphical **display** of **data** using **bars** of different heights where each bar **groups numbers into ranges**.
#
# - **Taller bars** show that **more data** falls in that range. They are **useful** in **identifying** the **distribution** of features.
#
# - For pandas hist plot official documentation click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html">**here**</a>.

# %%
fig, ax = plt.subplots(figsize=(10, 5))
bins = np.arange(0, 500, 50)
df_mcd['Serve_Size'].plot(kind='hist', bins=bins, ax=ax)
plt.xlabel("Serve_Size Buckets")
# Out:
# Text(0.5, 0, 'Serve_Size Buckets')

# %%
# MATPLOTLIB, SEABORN

# %%
df_mcd.columns
# Out:
# Index(['Unnamed: 0', 'Category', 'Item', 'Serve_Size', 'Energy', 'Protein',
#        'Total_Fat', 'Saturated_Fat', 'Trans_Fat', 'Cholestrol',
#        'Carbohydrates', 'Sugars', 'Dietary_Fibre', 'Sodium',
#        'High_Or_Low_Sugar'],
#       dtype='object')

# %%
fig, axis = plt.subplots(figsize=(14, 5))

sns.histplot(data=df_mcd['Serve_Size'], ax=axis, binwidth=50,
             kde=True
            )
plt.grid(linestyle=':')
plt.xlabel("Serve_Size Bucket")
plt.title("Distribution of Serve Size across Items")
# Out:
# Text(0.5, 1.0, 'Distribution of Serve Size across Items')

# %%
fig, ax = plt.subplots(figsize=(14, 4))
sns.histplot(data=df_mcd, x='Serve_Size', hue='Category', binwidth=50, multiple='dodge', kde=True)
# Out:
# <AxesSubplot:xlabel='Serve_Size', ylabel='Count'>

# %%
new_df = df_mcd.query("Category == 'Cold Beverages' or Category == 'Desserts'")

# %%
fig, axis = plt.subplots(figsize=(14, 5))
sns.histplot(data=new_df, x='Serve_Size', hue='Category', multiple='dodge', kde=True, binwidth=50, ax=axis)
# Out:
# <AxesSubplot:xlabel='Serve_Size', ylabel='Count'>

# %% [markdown]
# ### MULTIVARIATE BAR PLOTS

# %%
# CREATE A CHART SHOWING PROTEIN AND TOTAL FAT PER CATEGORY

# %%
multi_metric_df = df_mcd.groupby('Category').agg({'Protein': 'mean',
                                                  'Total_Fat': 'mean'})

# %%
fig, axis = plt.subplots(figsize=(14, 5))
multi_metric_df.plot(kind='bar', ax=axis)
plt.ylabel("Grams")
plt.title("Avegrage Protein & Fat per Category")
plt.grid(linestyle=':', axis='y')

# %%
# Creating a custom figure size of 15 X 7 inches
figure = plt.figure(figsize=[15, 7])

# Creating custom bins for the graph
bins = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]

# Using magic of pandas area() function
df_mcd['Serve_Size'].plot(kind='hist', bins=bins, color='brown')

# Changing x-ticks equal to custom bin values
plt.xticks(ticks=bins, size=12)

# Changing y-ticks ranging from 0 to 22 with step size of 3 and label size of 12
plt.yticks(ticks=np.arange(0, 22, 3), size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Serve Size', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Frequency', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Distribution of Serve Size Feature', size=16)

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# <a name = Section55></a>
# ### **5.5 KDE Plot**
#
# - This graph helps in visualizing the **distribution of data** over a **continuous interval** or **time period**.
#
#
# - This chart is a **variation of a Histogram** that uses **smoothing** technique to plot values.
#
#
# - The **peaks** of a **density plot** help display where **values are concentrated** over the **interval**.
#
#
# - **Advantage:** Better at determining the distribution shape because they're **unaffected** by **bins size**.
#
# - For pandas kde plot official documentation click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.kde.html">**here**</a>.

# %%
# Creating a custom figure size of 15 X 7 inches
figure = plt.figure(figsize=[15, 7])

# Using magic of pandas kde() function
df_mcd['Serve_Size'].plot.kde(color='black')

# Changing x-ticks ranging from -200 to 800 with step size of 50 and label size of 12
plt.xticks(ticks=np.arange(-200, 800, 50), size=12)

# Changing y-ticks labels size to 12
plt.yticks(size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Serve Size', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Density', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Density of Serve Size Feature', size=16)

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - The data in **Serve Size** column is somewhat following a **normal distribution**.
#
# **<center><h4>What is the difference between Bar plot and Histogram?</h4></center>**
#
# - **Histogram** represents **a range of values** whereas in **bar plot** each **bar represents** a **single value**.
#
#
# - However, since histograms break space up into even intervals, so __they don't deal very well with skewed data__.

# %% [markdown]
# <a name = Section56></a>
# ### **5.6 Donut Chart**
#
# - This graph is a **variation of a pie chart** except that it is hollow in the center which makes it look like a donut.
#
# - The pie charts are **sometimes criticised** for focusing readers on the **proportional areas** of the slices to one another.
#
# - This makes it tricky to see the differences between slices, especially when you try to __compare multiple pie charts together__.
#
# - A donut chart somewhat remedies this problem by **de-emphasizing** the use of the area.
#
# - Instead, readers focus more on reading the __length of the arcs__, rather than __comparing__ the proportions between __slices__.
#
# - For pandas pie plot official documentation click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html">**here**</a>.

# %%
# Creating a custom figure size of 10 X 10 inches
figure = plt.figure(figsize=[10, 10])

# Exploding space based on the number of categories
space = np.ones(11)/10

# Using magic of pandas pie() function
df_mcd['Category'].value_counts().plot(kind='pie', explode=space, fontsize=14, 
                                       autopct='%3.1f%%', wedgeprops=dict(width=0.15), 
                                       shadow=True, startangle=160, cmap='inferno', legend=True)

plt.ylabel(ylabel='Category', size=14)
plt.title(label='Donut Plot showing the proportion of each Category value', size=16)
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can **observe** the **share** of each Category value in the data.
#
# - **Larger strips** on the donut represents a **higher share** of a particular **Category**.
#
# - Here **Cold Beverages** category have the **highest share** with **21.7%** of samples.

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Bivariate Plotting**
# ---
#
# |<center>Scatter Plot</center>|<center>Hex Plot</center>|<center>Stacked Bar Chart</center>|<center>Bivariate Line Chart</center>|<center>Pair Plot</center>|
# |:--:|:--:|:--:|:--:|:--:|
# |<img src="https://i.imgur.com/bBj1G1v.png">|<img src="https://i.imgur.com/ChK9zR3.png">|<img src="https://i.imgur.com/KBloVHe.png">|<img src="https://i.imgur.com/C7kEWq7.png">|<img src="https://i.stack.imgur.com/WqpFb.png">|
# |df.plot.scatter()|df.plot.hex()|df.plot.bar(stacked=True)|df.plot.line()|sns.pairplot()|
#
# <center><h4><strong>Disclaimer:</strong> The images are only for illustration purpose. Please don't compare them with our data.</h4></center>
#
# - Data without relationships between variables is equivalent to a blank canvas.
#
# - To paint the picture in, we need to **understand** how variables **interact** with one another. For example,
#
#   - Does an increase in one variable correlate with an increase in another?
#
#   - Does it relate to a decrease somewhere else?
#
# - The best way to paint the picture is by using plots that enable these possibilities.

# %% [markdown]
# <a name = Section61></a>
# ### **6.1 Scatter Plot**
#
# - It is a **mathematical diagram** using **cartesian coordinates** to display values for typically two variables for a set of data.
#
# - It **maps** each variable of **interest to a point** in two-dimensional space.
#
# - For pandas scatter plot official documentation click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.scatter.html">**here**</a>.

# %%
# Using magic of pandas scatter() function along with implicit figure size of 15 X 7 inches
df_mcd.plot.scatter(x='Carbohydrates', y='Energy', color='purple', figsize=[15, 7])

# Changing x-ticks ranging from 0 to 90 with step size of 5 and label size of 12
plt.xticks(ticks=np.arange(0, 90, 5), size=12)

# Changing y-ticks ranging from 0 to 800 with step size of 50 and label size of 12
plt.yticks(ticks=np.arange(0, 800, 50), size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Carbohydrates', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Energy', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Energy vs Carbohydrates', size=16)

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - Here we can see that the variation of **Energy** increases with increase in **Carbohydrates**.
#
# - But the visual is **not that impactful**. We can use something better. What would that be?
#
# - I think you are guessing right. It is the trend line that we need to make an impact of the current visual.

# %% [markdown]
# <a name = Section62></a>
# ### **6.2 Regression Plot**
#
# -  It intends to add a visual guide that helps to **emphasize patterns** in a dataset during exploratory data analysis.
#
# - It creates a **regression line** between 2 parameters and helps to visualize their **linear relationships**.
#
# - For seaborn regression plot official documentation click <a href="https://seaborn.pydata.org/generated/seaborn.regplot.html">**here**</a>.

# %%
# Creating a custom figure size of 15 X 7 inches
figure = plt.figure(figsize=[15, 7])

# Using magic of seabron regplot() function
sns.regplot(x='Carbohydrates', y='Energy', data=df_mcd, color='brown')

# Changing x-ticks ranging from 0 to 90 with step size of 5 and label size of 12
plt.xticks(ticks=np.arange(0, 90, 5), size=12)

# Changing y-ticks ranging from 0 to 800 with step size of 50 and label size of 12
plt.yticks(ticks=np.arange(0, 800, 50), size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Carbohydrates', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Energy', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Energy vs Carbohydrates', size=16)

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - Here we can see the positive correlation of variation of **Energy** with respect to change in **Carbohydrates**.
#
# - As the **Carbohydrates** present in an item **increases** there's an increase in the **Energy** value.
#
# - This is power of regression plot!
#
# **Shortcomming:**
#
# - Scatterplot **doesn't care about** the **density mapping of points** at same place.
#
# - For example, let say there are two points that has same value of Carbohydrates and Energy i.e. (30, 50), (30, 50).
#
# - The **values** will be **overplotted** on the same place while we see there's only one point.
#
# - This isn't a problem if it happens just a few times. But with enough points the distribution starts to look like a **shapeless blob**.
#
# **Solution:**
# - An interesting way to solve the above mentioned problem is to use our next plot type, a **hexplot**.

# %% [markdown]
# <a name = Section63></a>
# ### **6.3 Hex Plot**
#
# -  A hexplot **aggregates points** in space into **hexagons**, and then colorize those hexagons.
#
# - For panda's hexbin plot official documentation click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.hexbin.html">**here**</a>.

# %%
# Using magic of pandas hexbin() function
df_mcd.plot.hexbin(x='Serve_Size', y='Energy', color='#4CB391', figsize=[15, 7], gridsize=25, sharex=False)

# Changing x-ticks ranging from 0 to 600 with step size of 50 and label size of 12
plt.xticks(ticks=np.arange(0, 500, 50), size=12)

# Changing y-ticks ranging from 0 to 800 with step size of 50 and label size of 12
plt.yticks(ticks=np.arange(0, 800, 50), size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Serve Size', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Energy', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Energy vs Serve Size', size=16)

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can observe that the **maximum density of points** lie in the **Serve Size** range of **80 to 280**.

# %% [markdown]
# <a name = Section64></a>
# ### **6.4 Stacked Bar Chart**
#
# - A stacked bar chart is one which **plots the variables one on top of the other**.
#
# - They share the **strengths** and **weaknesses** of **univariate** bar charts & work best for **nominal** and **ordinal** categorical variables.
#
# - **Limitations:**
#
#   - The **second variable** in a stacked plot must be a variable with a very **limited** number of possible **values**.
#
#   - **Difficulty in interpretation** of the plot if contrasting colors aren't used properly.
#
# - For pandas's barplot official documentation click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html">**here**</a>.

# %%
# Creating a custom figure size of 15 X 7 inches
figure, ax = plt.subplots(figsize=(15, 7))


(df_mcd
 .groupby(by=['Category'])
 [['Total_Fat','Saturated_Fat','Trans_Fat']]
 .median()
 .plot(kind='bar',stacked=True,  ax=ax))


# # Using magic of pandas bar() function for plotting stack bar plot
# df_mcd.groupby(by=['Category'])['Total_Fat'].mean().plot.bar(color='orange')
# df_mcd.groupby(by=['Category'])['Saturated_Fat'].mean().plot.bar(color='grey')
# df_mcd.groupby(by=['Category'])['Trans_Fat'].mean().plot.bar(color='red')

# Changing x-ticks label size to 12 and rotating to 90 degrees
plt.xticks(size=12, rotation=90)

# Changing y-ticks value using an array of 30 values with step size of 2
plt.yticks(ticks=np.arange(0, 30, 2), size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Category', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Fat Content', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Fat Content per Category', size=16)

# Setting up legend for the fat types
plt.legend(labels=('Total_Fat', 'Saturated_Fat', 'Trans_Fat'))

# Enabling grid for better precision view
plt.grid(linestyle=':')

# Dispaly the output by rendering visual on the screen
plt.show()
plt.tight_layout()

# %% [markdown]
# **Observation:**
#
# - Here we can see the amount of different **fats** in each category. **Saturated_Fat is red, Trans_Fat is blue** and **Total_Fat is yellow**.
#
#
# - **Trans fats** only occur in **small amounts in meat and milk fat**, that's why they show such a low content in the chart.
#
# - We can perform stacking for area charts also.

# %%
# Creating a custom figure size of 15 X 7 inches
figure = plt.figure(figsize=[15, 7])

# Using magic of pandas area() function for plotting stack area plot
(df_store
 .groupby(by=['Customers'])
 [['Revenue','Profits']]
 .mean()
 .plot(kind='area',stacked=True,cmap='coolwarm',figsize=(12,6)))

# Changing x-ticks ranging from 0 to 25000 with step size of 1500 and label size of 12
plt.xticks(ticks=np.arange(0, 25000, 1500), size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Customers', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Value', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Revenue and Profit per state', size=16)

# Setting up legend for the fat types
plt.legend(labels=('Revenue', 'Profits'), fontsize=12)

# Enabling grid for better precision view
plt.grid(b=True)

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can observe that the **revenue** and **profit** of store **increases** with the increase in **number of customers**.
#
# - **Profits** are always a **small portion** of the **total revenue**.

# %% [markdown]
# <a name = Section65></a>
# ### **6.5 Bivariate Line Chart**
#
# - A stacked line chart is one which **plots the variables one on top of the other** with continuous values.
#
# - The line chart is **easy**, **effective** and takes up **a little visual space** to overplot multiple lines on the same graph.
#
# - For pandas's lineplot official documentation click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.line.html">**here**</a>.

# %%
# Creating a custom figure size of 15 X 7 inches
figure = plt.figure(figsize=[15, 7])

# Using magic of pandas area() function for plotting stack area plot
df_mcd.groupby(by=['Serve_Size'])['Cholestrol'].mean().plot.line(color='green')
df_mcd.groupby(by=['Serve_Size'])['Total_Fat'].mean().plot.line(color='red')

# Changing x-ticks ranging from 0 to 500 with step size of 50 and label size of 12
plt.xticks(ticks=np.arange(0, 500, 50), size=12)

# Changing y-ticks ranging from 0 to 300 with step size of 50 and label size of 12
plt.yticks(ticks=np.arange(0, 300, 50), size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Serve Size', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Value', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Cholestrol and Total Fat vs Serve Size', size=16)

# Setting up legend for the fat types
plt.legend(labels=('Cholestrol (in mg)', 'Total_Fat (in g)'), fontsize=12)

# Enabling grid for better precision view
plt.grid(b=True)

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - For different **serve sizes** the amount of **Total Fat** (in grams) and **Cholestrol** (in miligrams) follows a **similar trend**.
#
# - As the amount of **Total Fat increases** the amount of **Cholestrol** also **increases** with it for each serve size.
#
#
# - Using a line chart this way **solves** the second **limitation of stacked plotting** i.e. interpretation of stacked plots.
#
# - We have plotted different variables, but still we are able to see the trend they all follow, clearly.

# %% [markdown]
# <a name = Section66></a>
# ### **6.6 Pair Plot**
#
# - To **plot pairwise relationship** in a dataset we use pair plot.
#
# - It shows the relationship of each variable to itself and other variables in a dataset **as matrix**.
#
# - The diagonal plots are the univariate plots as these plots show relationship of each variable to itself.
#
# - It is also **possible** to plot a **subset of variables** on the rows and columns.
#
# - For seaborn's pairplot official documentation click <a href="https://seaborn.pydata.org/generated/seaborn.pairplot.html">**here**</a>.

# %%
# Extracting a subset of features from the dataset
subset = df_mcd[['Energy', 'Total_Fat', 'Sugars', 'Carbohydrates', 'Protein']]

# Using magic of pandas area() function for plotting stack area plot
sns.pairplot(data=subset, size=2.5, diag_kind='kde')

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - The **highest positive correlation** can be seen between **Energy** and **Total_Fat** columns.
#
#
# - The **diagonal elements** in a pairplot shows the **frequency distribution** of that column.

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Multivariate Plotting**
# ---
#
# |<center>Multivariate Scatter Plot</center>|<center>Grouped Box Plot</center>|<center>Heatmap</center>|<center>Parallel Coordinates</center>|<center>Swarm plot</center>|
# |:--:|:--:|:--:|:--:|:--:|
# |<img src="https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/chart_colur_shape.png">|<img src="https://i.imgur.com/3qEqPoD.png">|<img src="https://i.imgur.com/1fmV4M2.png">|<img src="https://i.imgur.com/H20s88a.png">|<img src="https://seaborn.pydata.org/_images/seaborn-swarmplot-5.png">|
# |sns.scatterplot()|sns.boxplot()|sns.heatmap()|pd.plotting.parallel_coordinates()|sns.swarmplot()|
#
# <center><h4><strong>Disclaimer:</strong> The images are only for illustration purpose. Please don't compare them with our data.</h4></center>
#
# - In this section we'll explore multivariate charts.
#
# - The most obvious way to plot lots of variables is to augment the visualizations with even more visual variables.
#
# - A visual variable is any visual dimension or marker that we can use to perceptually distinguish two data elements from one another.
#
# - Examples include size, color, shape, and one, two, and even three-dimensional positions.
#
# - Good multivariate data displays make efficient, easily-interpretable use of these parameters.

# %% [markdown]
# <a name = Section71></a>
# ### **7.1 Multivariate Scatter Plots**
#
#
# - The multivariate scatter plot **uses three variables** x, y and hue for interactive visualization.
#
# - For seaborn's scatterplot official documentation click <a href="https://seaborn.pydata.org/generated/seaborn.scatterplot.html">**here**</a>.

# %%
# Creating a custom figure size of 15 X 7 inches
figure = plt.figure(figsize=[15, 7])

# Using magic of seaborn's scatterplot() function
sns.scatterplot(x='Sugars', y='Energy', hue='Category', data=df_mcd)

# Changing x-ticks ranging from 0 to 81 with step size of 5 and label size of 12
plt.xticks(ticks=np.arange(0, 81, 5), size=12)

# Changing y-ticks ranging from 0 to 801 with step size of 50 and label size of 12
plt.yticks(ticks=np.arange(0, 801, 50), size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Sugars', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Energy', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Energy Variation with Sugars per Category', size=16)

# Setting up legend for the fat types
plt.legend(fontsize=12)

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - The **Sandwiches and Wraps** category have the **highest Energy** output with the **least Sugar** content.

# %% [markdown]
# <a name = Section72></a>
# ### **7.2 Grouped Boxplot**
#
# - A Box and Whisker Plot (or Box Plot) is a convenient way of visually displaying the **data distribution** through their **quartiles**.
#
# - The term “box plot” comes from the fact that the graph looks like a **rectangle with lines extending** from the top and bottom.
#
# - The lines extending parallel from the boxes are known as the **“whiskers”** indicate variability outside the upper and lower quartiles.
#
# - They can be drawn either vertically or horizontally and help in plotting outliers as individual dots that are in-line with whiskers
#
# - They have the **advantage** of taking up **less space**, which is **useful** when **comparing distributions** between many groups or datasets.
#
#
#
# - For seaborn's boxplot official documentation click <a href="https://seaborn.pydata.org/generated/seaborn.boxplot.html">**here**</a>.

# %%
# Creating a custom figure size of 15 X 7 inches
figure = plt.figure(figsize=[15, 7])

# Using magic of seaborn's boxplot() function
sns.boxplot(x='State', y='Revenue', palette='rainbow', data=df_store)

# Changing x-ticks ranging from 0 to 81 with step size of 5 and label size of 12
plt.xticks(size=12)

# Changing y-ticks ranging from 0 to 801 with step size of 50 and label size of 12
plt.yticks(size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='State', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Revenue', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Revenue per State', size=16)

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - **Revenue** in **DL (Delhi)** is usually **higher** than the rest of the states.
#
# - Each **State** has **skewed** data as the median line is not in the middle of the whiskers for each state.
#
# - Since there's **only one sample** (row) with **State MH**, so the boxplot shows just a single line for all the values.

# %% [markdown]
# **Summarization:**
#
# - It is **difficult** to squeeze enough **dimensions** onto a **plot** without hurting its **interpretability**.
#
# - Very **busy plots** are naturally very **hard to interpret**. Hence highly multivariate can be difficult to use.
#
# - Another way to plot many features while **circumnavigating** this problem is to use **summarization**.
#
# - It refers to the **creation** and **addition** of new **variables** by **mixing** and **matching** the **information** provided in the **old ones**.
#
# - It allows us to **boil down** potentially very **complicated relationships** into simpler ones.

# %% [markdown]
# <a name = Section73></a>
# ### **7.3 Heat Map**
#
# - A data visualization technique that **shows magnitude** of a phenomenon as color in **two dimensions**.
#
# - The **variation** in color may be by **hue or intensity**, giving obvious visual cues about how the phenomenon is clustered or varies over space.
#
# - Typically, all the **rows** are **one category** and all the **columns** are **another category**.
#
# - The individual rows and columns are divided into the subcategories, which all match up with each other in a matrix.
#
# - The **cells** contained within the table either contain **colour-coded** categorical data or numerical data.
#
# - A **legend** is also **used alongside** a Heatmap in order to read the graph successfully.
#
# - For seaborn's heatmap official documentation click <a href="https://seaborn.pydata.org/generated/seaborn.heatmap.html">**here**</a>.

# %%
# Creating a custom figure size of 15 X 7 inches
figure = plt.figure(figsize=[15, 7])

# Using magic of seaborn's heatmap() function
sns.heatmap(data=df_mcd.corr(), annot=True, cmap='viridis')

# Changing x-ticks label size to 12
plt.xticks(size=12, rotation=90)

# Changing y-ticks label size to 12
plt.yticks(size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Feature Space X', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Feature Space Y', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Correlation of Features', size=16)

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - The **diagonal cells** of above matrix shows the **auto-correlation** of variable which is always equal to 1.
#
# - Correlation varies from -1 to +1 and its interpretation works as follows:
#   - Value close to **-1** refers to **strong negative correlation**.
#
#   - Value close to **+1** refers to **strong positive correlation**.
#
#   - Value close to **0** referst to **weak correlation**.
#
# - **Variables** with **strong correlation** are selected as the most **probable candidates** for **model builing**.
#
# - Heatmaps are better suited to **display** a more **generalised view** of numerical data.
#
# - The reason is their reliance on colour to communicate values is very clear.

# %% [markdown]
# <a name = Section74></a>
# ### **7.4 Parallel Coordinates**
#
# - This type of visualisation is used for plotting multivariate, numerical data.
#
# - They are **ideal** for **comparing many variables together** and understanding the relationships between them.
#
# - Each variable is given its own axis and all the axes are placed in parallel to each other.
#
# - They can **have** a **different or common scale** for each variable to display the unit of measurement.
#
# - Values are plotted as a **series of lines** that connected across all the axes.
#
# - This means that **each line** is a **collection of points** placed on each axis, that have all been connected together.
#
# - For pandas's parallel_coordinates official documentation click <a href="https://pandas.pydata.org/docs/reference/api/pandas.plotting.parallel_coordinates.html">**here**</a>.

# %% [markdown]
# - Before plotting the data we can normalize all the variables using a scaling method.
#
# - We will be using min-max scaling: $\large\frac{x-min(x_i)}{max(x_i)-min(x_i)}$

# %%
# # Copy original data to an object
# mcd_normal = df_mcd.copy()

# # Initiate a list of categorical features
# cat_feats = ['Category', 'Item', 'Sodium', 'High_Or_Low_Sugar']

# # Iterate over the data variables to perform scaling
# for col in mcd_normal.columns:

#   # Check if the categorical variables are present in the dataset
#   if col not in cat_feats:
    
#     # Perform min-max scaling
#     mcd_normal[col] = (mcd_normal[col] - mcd_normal[col].min()) / (mcd_normal[col].max() - mcd_normal[col].min())

# # Dispaly top 5 rows
# mcd_normal.head()

# %%
# # Creating a custom figure size of 15 X 7 inches
# figure = plt.figure(figsize=[15, 7])

# # Using magic of pandas's parallel_coordinates() function
# pd.plotting.parallel_coordinates(frame=mcd_normal, class_column='High_Or_Low_Sugar', 
#                                  colormap='viridis', cols=['Energy', 'Protein', 'Total_Fat', 'Carbohydrates'])

# # Changing x-ticks label size to 12
# plt.xticks(size=12)

# # Changing y-ticks label size to 12
# plt.yticks(size=12)

# # Labelling x-axis with a custom label and size of 14
# plt.xlabel(xlabel='Numerical Features', size=14)

# # Labelling y-axis with a custom label and size of 14
# plt.ylabel(ylabel='Values', size=14)

# # Labelling title with a custom label and size of 14
# plt.title(label='Energy, Protein, Total Fat, Carbohydrates vs Sugar Levels', size=16)

# # Dispaly the output by rendering visual on the screen
# plt.show()

# %% [markdown]
# **Observation:**
#
# - We can see the variation in values of different numerical columns of mcd_normal dataframe.

# %% [markdown]
# <a name = Section75></a>
# ### **7.5 Violin Plot**
#
# - This plot is used to **visualise** the **distribution** of the data and its probability density.
#
# - This plot is a **combination** of a **Box Plot** and a **Density Plot** that is rotated and placed on each side.
#
# - The **white dot** in the **middle** is the **median** value and the **thick black bar** in the center represents the **interquartile range**.
#
# - The thin black line extended from it represents the upper (max) and lower (min) adjacent values in the data.
#
# - **Sometimes** the graph **marker** is **clipped** from the **end of the line**.
#
# - Box plots tends to limit their data display because they hide the distribution of the data.
#
# - For example, with Box Plots, you can't see if the distribution is bimodal or multimodal.
#
# - For seaborn's violinplot official documentation click <a href="https://seaborn.pydata.org/generated/seaborn.violinplot.html">**here**</a>.

# %%
# Creating a custom figure size of 15 X 7 inches
figure = plt.figure(figsize=[15, 7])

# Using magic of seaborn's violinplot() function
sns.violinplot(x='High_Or_Low_Sugar', y='Energy', data=df_mcd, palette='magma')

# Changing x-ticks label size to 12
plt.xticks(size=12)

# Changing y-ticks ranging from -200 to 1001 with step size of 50 and label size of 12
plt.yticks(ticks=np.arange(-200, 1001, 50), size=12)

# Labelling x-axis with a custom label and size of 14
plt.xlabel(xlabel='Sugar Level', size=14)

# Labelling y-axis with a custom label and size of 14
plt.ylabel(ylabel='Energy', size=14)

# Labelling title with a custom label and size of 14
plt.title(label='Energy Variation with Sugar', size=16)

# Enable grid
plt.grid(b=True, axis='y')

# Dispaly the output by rendering visual on the screen
plt.show()

# %% [markdown]
# **Observation:**
#
# - From the above violin plot we can clearly see the distribution on the basis of Sugar Level and Energy.
#
# - The **items** having **high sugar** content have **lower energy** when compared to items having low sugar content.

# %% [markdown]
# **<center><h3>That's all Folks!</h3></center>**
